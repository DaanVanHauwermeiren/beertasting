# %% [markdown]
# # load libs

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport beertasting
# %matplotlib inline

# %% [markdown]
# # initialise the tasting

# %% [markdown]
# tasting can be initialised with some dummy data so that plotting can be tested

# %%
tasting = beertasting.Beertasting(dummyinit=False)
# Out:
# initialising an empty tasting object!

# %% [markdown]
# saving a tasting:

# %% [raw]
# tasting.save_tasting()

# %% [markdown]
# loading a previous tasting

# %% [raw]
# tasting.load_tasting("./stored_tastings/2018_07_01__10:01:33", overwrite=False)

# %% [markdown]
# # example tastings: howto add them

# %% [raw]
# # dummy tastings
#
# ## round 1
#
# tasting.taste_beer({
#         "taster": "Daan",
#         "beer": 'cara',
#         "score": 8,
#         "hoppig": 3,
#         "moutigheid": 3,
#     })
#
# tasting.taste_beer({
#         "taster": "Daan",
#         "beer": 'cristal',
#         "score": 10,
#         "kleur": "blond",
#         "hoppig": 4,
#         "moutigheid": 4,
#     })
#
# tasting.taste_beer({
#         "taster": "Astrid",
#         "beer": 'cara',
#         "score": 7
#     })
#
# tasting.taste_beer({
#         "taster": "Astrid",
#         "beer": 'cristal',
#         "score": 3,
#         "kleur": "blond"
#     })
#
# ## round 2
#
# tasting.taste_beer({
#         "taster": "Daan",
#         "beer": 'cara',
#         "score": 9
#     })
#
# tasting.taste_beer({
#         "taster": "Daan",
#         "beer": 'cristal',
#         "score": 9,
#         "kleur": "blond"
#     })
#
# tasting.taste_beer({
#         "taster": "Astrid",
#         "beer": 'cara',
#         "score": 8
#     })
#
# tasting.taste_beer({
#         "taster": "Astrid",
#         "beer": 'cristal',
#         "score": 4,
#         "kleur": "blond"
#     })

# %% [markdown]
# # the tastings themselves

# %% [raw]
# << add tastings >>

# %% [raw]
# tasting.taste_beer({
#         "taster": "Spouw McBarfstein",
#         "beer": 'deneersten',
#         "score": 4,
#         "kleur": "blond",
#         # SPLIT THIS UP TO AVOID LISTS?
#         "aroma": ["rood fruit", "koffie", "noten", "gerookt", "citrus"],
#         "smaak": ["rood fruit", "koffie", "noten", "gerookt", "citrus"],
#         "mond": ["waterig", "vol", "kleverig", "sprankelend", "droog"],
#         "nasmaak": ["zoet", "zuur", "blijft hangen"],
#         "hoppig": 4,
#         "zoet": 4,
#         "zuur": 3,
#         "bitter": 5,
#         "vol": 2,
#     })

# %% [markdown]
# ## beer 1

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'bavaria pils',
        "score": 2,
        "hoppig": 4,
        "zoet": 4,
        "zuur": 2,
        "bitter": 2,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'bavaria pils',
        "score": 2,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 2,
        "bitter": 2,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'bavaria pils',
        "score": 2,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 1,
        "bitter": 2,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'bavaria pils',
        "score": 2,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 1,
        "bitter": 2,
        "vol": 1,
    })

# %%
tasting.taste_beer({
        "taster": "jonas",
        "beer": 'bavaria pils',
        "score": 4,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 0,
        "bitter": 0,
        "vol": 1,
    })

# %% [markdown]
# ## beer twee

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'jupiler',
        "score": 2,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 1,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'jupiler',
        "score": 1,
        "hoppig": 3,
        "zoet": 3,
        "zuur": 4,
        "bitter": 4,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'jupiler',
        "score": 3,
        "hoppig": 4,
        "zoet": 1,
        "zuur": 3,
        "bitter": 4,
        "vol": 3,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'jupiler',
        "score": 3,
        "hoppig": 3,
        "zoet": 1,
        "zuur": 1,
        "bitter": 3,
        "vol": 3,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'jupiler',
        "score": 3,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 2,
        "bitter": 2,
        "vol": 2,
        "opmerking": "stella artois"
    })

# %% [markdown]
# ## beer drie

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'heineken',
        "score": 2,
        "hoppig": 1,
        "zoet": 1,
        "zuur": 1,
        "bitter": 3,
        "vol": 1,
        "opmerking": "niet actief slecht, saai; bavaria"
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'heineken',
        "score": 2,
        "hoppig": 2,
        "zoet": 1,
        "zuur": 2,
        "bitter": 2,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'heineken',
        "score": 2,
        "hoppig": 2,
        "zoet": 2,
        "zuur": 2,
        "bitter": 3,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'heineken',
        "score": 1,
        "hoppig": 1,
        "zoet": 1,
        "zuur": 1,
        "bitter": 3,
        "vol": 1,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'heineken',
        "score": 1,
        "hoppig": 1,
        "zoet": 2,
        "zuur": 2,
        "bitter": 2,
        "vol": 1,
    })

# %% [markdown]
# ## beer vier

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'tyskie',
        "score": 2,
        "hoppig": 3,
        "zoet": 3,
        "zuur": 2,
        "bitter": 2,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'tyskie',
        "score": 1,
        "hoppig": 1,
        "zoet": 1,
        "zuur": 3,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'tyskie',
        "score": 2,
        "hoppig": 1,
        "zoet": 1,
        "zuur": 3,
        "bitter": 4,
        "vol": 3,
        "opmerking": "metalig"
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'tyskie',
        "score": 3,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 1,
        "bitter": 3,
        "vol": 3,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'tyskie',
        "score": 2,
        "hoppig": 1,
        "zoet": 2,
        "zuur": 3,
        "bitter": 3,
        "vol": 3,
    })

# %% [markdown]
# ## bier vijf

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'maes',
        "score": 1,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 2.5,
        "bitter": 2,
        "vol": 1,
        "opmerking": "het zou echt grappig zijn als dit pils 13 is; gok jupiler"
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'maes',
        "score": 1,
        "hoppig": 1,
        "zoet": 2,
        "zuur": 4,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'maes',
        "score": 2,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 1,
        "bitter": 3,
        "vol": 1,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'maes',
        "score": 2,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 1,
        "bitter": 2,
        "vol": 4,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'maes',
        "score": 1,
        "hoppig": 1,
        "zoet": 0,
        "zuur": 4,
        "bitter": 3,
        "vol": 3,
    })

# %% [markdown]
# ## bier zes

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'brouwers pils',
        "score": 4,
        "hoppig": 4,
        "zoet": 1,
        "zuur": 1,
        "bitter": 4,
        "vol": 5,
        "opmerking": "pils 13"
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'brouwers pils',
        "score": 2,
        "hoppig": 2,
        "zoet": 1,
        "zuur": 1,
        "bitter": 4,
        "vol": 2.5,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'brouwers pils',
        "score": 4,
        "hoppig": 4,
        "zoet": 1,
        "zuur": 2,
        "bitter": 4,
        "vol": 3,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'brouwers pils',
        "score": 4,
        "hoppig": 4,
        "zoet": 1,
        "zuur": 1,
        "bitter": 4,
        "vol": 3,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'brouwers pils',
        "score": 4,
        "hoppig": 4,
        "zoet": 1,
        "zuur": 3,
        "bitter": 4,
        "vol": 4,

    })

# %% [markdown]
# ## bier zeven

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'pils 13',
        "score": 5,
        "hoppig": 5,
        "zoet": 1,
        "zuur": 3,
        "bitter": 5,
        "vol": 5,
        "opmerking": "pils 13"
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'pils 13',
        "score": 1,
        "hoppig": 5,
        "zoet": 2,
        "zuur": 3,
        "bitter": 5,
        "vol": 3,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'pils 13',
        "score": 4,
        "hoppig": 5,
        "zoet": 1,
        "zuur": 3,
        "bitter": 5,
        "vol": 5,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'pils 13',
        "score": 5,
        "hoppig": 5,
        "zoet": 1,
        "zuur": 2,
        "bitter": 5,
        "vol": 5,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'pils 13',
        "score": 4,
        "hoppig": 5,
        "zoet": 1,
        "zuur": 4,
        "bitter": 5,
        "vol": 5,

    })

# %% [markdown]
# ## bier acht

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'warsteiner',
        "score": 0,
        "hoppig": 1,
        "zoet": 5,
        "zuur": 1,
        "bitter": 2,
        "vol": 2,
        "opmerking": "jupiler"
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'warsteiner',
        "score": 3,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 1,
        "bitter": 1,
        "vol": 3,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'warsteiner',
        "score": 1,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 1,
        "bitter": 2,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'warsteiner',
        "score": 2,
        "hoppig": 2,
        "zoet": 4,
        "zuur": 1,
        "bitter": 3,
        "vol": 4,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'warsteiner',
        "score": 3,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 1,
        "bitter": 2,
        "vol": 3,
        "opmerking": "jupiler"
    })

# %% [markdown]
# ## bier negen

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'stella artois',
        "score": 1,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 1,
        "bitter": 2,
        "vol": 2,
        "beer": 'stella artois; gewoon goor',
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'stella artois',
        "score": 1.75,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 1,
        "bitter": 2,
        "vol": 0,
        "opmerking": "jupiler"
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'stella artois',
        "score": 1,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 2,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'stella artois',
        "score": 2,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 1,
        "bitter": 2,
        "vol": 3,
    })


tasting.taste_beer({
        "taster": "jonas",
        "beer": 'stella artois',
        "score": 3,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 2,
        "bitter": 1,
        "vol": 3,
    })

# %% [markdown]
# ## bier tien

# %%
tasting.taste_beer({
        "taster": "joeri",
        "beer": 'grolsch',
        "score": 2,
        "hoppig": 1,
        "zoet": 3,
        "zuur": 2,
        "bitter": 2,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "benjamin",
        "beer": 'grolsch',
        "score": 3,
        "hoppig": 1,
        "zoet": 1,
        "zuur": 2,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "siebe",
        "beer": 'grolsch',
        "score": 3,
        "hoppig": 2,
        "zoet": 3,
        "zuur": 3,
        "bitter": 3,
        "vol": 2,
    })

tasting.taste_beer({
        "taster": "daan",
        "beer": 'grolsch',
        "score": 3,
        "hoppig": 1,
        "zoet": 4,
        "zuur": 1,
        "bitter": 3,
        "vol": 3,
    })

tasting.taste_beer({
        "taster": "jonas",
        "beer": 'grolsch',
        "score": 2,
        "hoppig": 0,
        "zoet": 2,
        "zuur": 3,
        "bitter": 2,
        "vol": 2,
    })

# %% [markdown]
# # some general info about the tastings

# %% [markdown]
# who tasted?

# %%
tasting.get_tasters()
# Out:
# ['joeri', 'benjamin', 'siebe', 'daan', 'jonas']

# %% [markdown]
# what beers were tasted?

# %%
tasting.get_tested_beers()
# Out:
# ['bavaria pils',
#  'jupiler',
#  'heineken',
#  'tyskie',
#  'maes',
#  'brouwers pils',
#  'pils 13',
#  'warsteiner',
#  'stella artois',
#  'grolsch']

# %% [markdown]
# what attributes of the beer were logged?

# %%
tasting.get_tested_attributes()
# Out:
# ['bitter', 'hoppig', 'opmerking', 'score', 'vol', 'zoet', 'zuur']

# %%
tasting.get_tested_attributes(includetype=True)
# Out:
# bitter         numerical
# hoppig         numerical
# opmerking    categorical
# score          numerical
# vol            numerical
# zoet           numerical
# zuur           numerical
# dtype: object

# %% [markdown]
# # plotting the results

# %% [markdown]
# split by numerical and categorical tested attributes

# %% [markdown]
# ## numerical scores

# %% [markdown]
# ### summarise the attributes for one beer

# %%
tasting.plot_beer_summary("bavaria pils");

# %% [raw]
# tasting.plot_beer_summary_all();

# %% [markdown]
# ### plot one numerical attribute

# %%
tasting.plot_beer_attribute("hoppig", splitbytaster=False);

# %%
tasting.plot_beer_attribute("bitter", splitbytaster=False);

# %%
fig, ax = tasting.plot_beer_attribute("score", splitbytaster=False);

# %% [markdown]
# ## categorical attributes

# %%
tasting.plot_beer_categorical_attribute("kleur")
# Out:
# (<matplotlib.figure.Figure at 0x7fc2a7f2f400>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc2a4569048>)

# %% [markdown]
# ## taste profile

# %%
tasting.plot_heatmap(
    #"daan"
);

# %%
tasting.plot_heatmap(
    "daan"
);

# %% [markdown]
# ## regression of attributes

# %%
g = tasting.plot_regression("score", "hoppig",
                               splitbytaster=True, #"taster",
                               order=1, #2
                               );

# %% [markdown]
# # get the raw data

# %% [raw]
# df = tasting.datatable

# %% [raw]
# df

# %% [raw]
# df.groupby(["taster", "beer"]).mean()

# %% [raw]
# df.groupby(["beer", "taster"]).mean()

# %% [raw]
# df.groupby(["beer"]).mean()

# %% [raw]
# df.loc["Beer_A", :]["kleur"].value_counts()

# %% [markdown]
# # zandbak

# %% [raw]
# import pandas as pd

# %% [raw]
# pd.get_dummies(tasting.datatable["kleur"])#.groupby(["beer"]).sum()

# %% [markdown]
# # ideas / notes

# %% [raw]
# iets met een smaakprofiel?
#
# optimaal profiel?
#
# meer opties testen
#
# howto: get the best beer
#
# limits: 0 - 10 ??
#
# regression: make it interactive
